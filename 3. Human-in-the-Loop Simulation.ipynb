# %%
using JSON
using HDF5
using JLD
using Interact
using Interpolations
using Plots
using StaticArrays
using TrafficWeavingPlanner
using DifferentialDynamicsModels
using LinearDynamicsModels

if isfile("config.json")
    config = JSON.parsefile("config.json")
else
    error("Please run setup.py in this directory before running any .ipynb's.")
end
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>
# Dict{String,Any} with 4 entries:
#   "catkin_ws_dir"           => "/home/schmrlng/catkin_ws"
#   "models_dir"              => "/data/trafficweaving/models"
#   "feature_extraction_dict" => "slim"
#   "data_dir"                => "/data/trafficweaving"

# %%
array_name = "trajectories_$(config["feature_extraction_dict"])"
base_filename = joinpath(config["data_dir"], array_name)
train_data = Dict(k => permutedims(v, ndims(v):-1:1) for (k,v) in h5open(read, base_filename * "_train.h5"))

y_top = Float32(mean([y for y in train_data["car1"][:,1,2] if y > -4]))
y_bot = Float32(mean([y for y in train_data["car1"][:,1,2] if y < -4]))
xdd_choices = Float32[0, -3, 4, -6]
y_targets = [y_top, y_bot]
tibvp = SteeringBVP(TripleIntegratorDynamics(1, Float32), TimePlusQuadraticControl(SMatrix{1,1}(Float32(1e-3))))
                                        
include("traffic_weaving_control.jl")
nothing
# Out:
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:9
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near In[2]:9

# %%
scenario_setup = Dict("xh" => -141,
                      "yh" => y_top,
                      "vh" => 28,
                      "xr" => -141,
                      "yr" => y_bot,
                      "vr" => 30)
# Out:
# Dict{String,Any} with 6 entries:
#   "xh" => -141
#   "yh" => -1.83284
#   "yr" => -6.09485
#   "xr" => -141
#   "vh" => 28
#   "vr" => 30

# %%
TrafficWeavingPlanner.setup_simulator(xh=scenario_setup["xh"], yh=scenario_setup["yh"], vh=scenario_setup["vh"])
TrafficWeavingPlanner.reset_simulator()

# %%
fname = "hitl-" * Dates.format(now(), "yyyy-mm-dd_HH.MM.SS") * ".jld"
car1, car2 = dynamic_trial(xdd_choices, y_targets, tibvp, Float32[scenario_setup["xr"],
                                                                  scenario_setup["yr"],
                                                                  scenario_setup["vr"],0,0,0]);
save("/home/schmrlng/ICRA18/" * fname, "car1", car1, "car2", car2)

# %%
visualize_predictions(load("HITL_samples/fight_cut_behind.jld"))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="800" height="900" viewBox="0 0 800 900">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="800" height="900"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 0,900 800,900 800,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="180" y="90" width="631" height="631"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 39.1436,275.813 380.315,275.813 380.315,31.4961 39.1436,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="31" width="342" height="245"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,272.149 39.1436,35.1608
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.199,272.149 149.199,35.1608
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   259.254,272.149 259.254,35.1608
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.309,272.149 369.309,35.1608
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,275.813 375.197,275.813
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,214.734 375.197,214.734
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,153.655 375.197,153.655
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,92.5754 375.197,92.5754
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.2612,31.4961 375.197,31.4961
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,275.813 380.315,275.813
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,275.813 39.1436,31.4961
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,275.813 39.1436,272.149
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.199,275.813 149.199,272.149
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   259.254,275.813 259.254,272.149
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.309,275.813 369.309,272.149
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,275.813 44.2612,275.813
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,214.734 44.2612,214.734
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,153.655 44.2612,153.655
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,92.5754 44.2612,92.5754
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,31.4961 44.2612,31.4961
#   "/>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.1436, 291.113)" x="39.1436" y="291.113">-150</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.199, 291.113)" x="149.199" y="291.113">-100</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 259.254, 291.113)" x="259.254" y="291.113">-50</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor